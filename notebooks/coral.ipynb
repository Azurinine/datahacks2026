# %%
import pandas as pd

coral = pd.read_csv('/Users/laurenlee/Desktop/datahacks2026/data/coral.csv', 
                 encoding='latin1',
                 low_memory=False)

# %%
coral[coral['ScientificName'] == 'sebastolobus']
# Out:
# Empty DataFrame
# Columns: [ScientificName, Ocean, latitude, longitude, DepthInMeters, ObservationYear, IndividualCount, CategoricalAbundance, Density, Condition, Temperature, Salinity, pH, pHscale]
# Index: []
